# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Weather.txt")

# %%
df
# Out:
#                       DateTime          TodaysCondition  HTempC  LTempC  \
# 0  January 07, 2019 at 09:00AM   Isolated Thunderstorms      39      24
# 1  January 07, 2019 at 10:00AM   Isolated Thunderstorms      39      24
# 2  January 07, 2019 at 11:00AM            Partly Cloudy      39      24
# 3  January 07, 2019 at 12:00PM   Isolated Thunderstorms      38      24
# 4  January 07, 2019 at 01:00PM  Scattered Thunderstorms      39      24
# 5  January 07, 2019 at 02:00PM  Scattered Thunderstorms      39      24
# 6  January 07, 2019 at 03:00PM  Scattered Thunderstorms      39      24
#
#    CurrTemp       CurrCond  WSpeedKmh  Direction  UV  Hum
# 0        29          Sunny         14      North   4   66
# 1        32          Sunny         16      North   7   56
# 2        33          Sunny         18      North  11   53
# 3        36           Fair         18      North  11   45
# 4        37  Partly Cloudy         18      North  11   41
# ...

# %%
pd.read_html("https://www.wunderground.com/history/daily/br/serop%C3%A9dica/SBSC/date/2019-1-7?cm_ven=localwx_history")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-e7fedb56c51f> in <module>()
# ----> 1 pd.read_html("https://www.wunderground.com/history/daily/br/serop%C3%A9dica/SBSC/date/2019-1-7?cm_ven=localwx_history")
#
# ~/bin/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#     985                   decimal=decimal, converters=converters, na_values=na_values,
#     986                   keep_default_na=keep_default_na,
# --> 987                   displayed_only=displayed_only)
#
# ~/bin/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     813             break
#     814     else:
# ...
