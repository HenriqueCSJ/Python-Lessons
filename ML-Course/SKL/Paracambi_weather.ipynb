# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/home/henrique/Coding/GitHub/Python-Lessons/ML-Course/pbi1.csv")

# %%
df
# Out:
#                         DateTime          TodaysCondition  HTempC  LTempC  \
# 0    January 07, 2019 at 09:00AM   Isolated Thunderstorms    39.0      24
# 1    January 07, 2019 at 10:00AM   Isolated Thunderstorms    39.0      24
# 2    January 07, 2019 at 11:00AM            Partly Cloudy    39.0      24
# 3    January 07, 2019 at 12:00PM   Isolated Thunderstorms    38.0      24
# 4    January 07, 2019 at 01:00PM  Scattered Thunderstorms    39.0      24
# 5    January 07, 2019 at 02:00PM  Scattered Thunderstorms    39.0      24
# 6    January 07, 2019 at 03:00PM  Scattered Thunderstorms    39.0      24
# 7    January 07, 2019 at 04:00PM      Thunderstorms Early     NaN      24
# 8    January 07, 2019 at 05:00PM      Thunderstorms Early     NaN      24
# 9    January 07, 2019 at 06:00PM      Thunderstorms Early     NaN      24
# 10   January 07, 2019 at 06:00PM      Thunderstorms Early     NaN      24
# 11   January 07, 2019 at 07:00PM      Thunderstorms Early     NaN      24
# ...

# %%
df["DateTime"] = pd.to_datetime(df["DateTime"], infer_datetime_format=True)

# %%
df.columns
# Out:
# Index(['DateTime', 'TodaysCondition', 'HTempC', 'LTempC', 'CurrTemp',
#        'CurrCond', 'WSpeedKmh', 'Direction', 'UV', 'Hum'],
#       dtype='object')

# %%
df.drop(['TodaysCondition', 'HTempC', 'LTempC'], axis=1, inplace=True)

# %%
df
# Out:
#                DateTime  CurrTemp                 CurrCond  WSpeedKmh  \
# 0   2019-01-07 09:00:00        29                    Sunny         14
# 1   2019-01-07 10:00:00        32                    Sunny         16
# 2   2019-01-07 11:00:00        33                    Sunny         18
# 3   2019-01-07 12:00:00        36                     Fair         18
# 4   2019-01-07 13:00:00        37            Partly Cloudy         18
# 5   2019-01-07 14:00:00        38            Partly Cloudy         18
# 6   2019-01-07 15:00:00        39            Partly Cloudy         18
# 7   2019-01-07 16:00:00        38            Partly Cloudy         16
# 8   2019-01-07 17:00:00        38            Partly Cloudy         13
# 9   2019-01-07 18:00:00        38                     Fair         11
# 10  2019-01-07 18:00:00        38                     Fair         11
# 11  2019-01-07 19:00:00        36  Showers in the Vicinity         10
# ...

# %%
plt.figure(figsize=(12, 7))
sns.lineplot(x="DateTime", y="CurrTemp", data=df)
sns.lineplot(x="DateTime", y="Hum", data=df)

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#            CurrTemp  WSpeedKmh        UV       Hum
# CurrTemp   1.000000   0.476398  0.746477 -0.957594
# WSpeedKmh  0.476398   1.000000  0.549484 -0.492202
# UV         0.746477   0.549484  1.000000 -0.702621
# Hum       -0.957594  -0.492202 -0.702621  1.000000

# %%
sns.heatmap(df.corr(), annot_kws="CurrTemp")

# %%
sns.distplot(df["CurrTemp"])

# %%
day = df[(df["DateTime"].dt.hour >= 8) & (df["DateTime"].dt.hour <= 17)]

# %%
plt.figure(figsize=(12, 10))
sns.countplot(x="CurrTemp", data=day, palette="viridis")
#sns.lineplot(x="DateTime", y="Hum", data=day)

# %%
sns.pairplot(day, hue="UV")
