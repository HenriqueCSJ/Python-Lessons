# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("RJ_111961.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31200 entries, 0 to 31199
# Data columns (total 11 columns):
# Estacao                      31200 non-null int64
# Data                         31200 non-null datetime64[ns]
# Hora                         31200 non-null object
# Precipitacao                 13304 non-null float64
# TempMaxima                   15840 non-null float64
# TempMinima                   15047 non-null float64
# Insolacao                    9855 non-null float64
# Evaporacao Piche             15014 non-null float64
# Temp Comp Media              13497 non-null float64
# Umidade Relativa Media       13394 non-null float64
# Velocidade do Vento Media    12072 non-null float64
# dtypes: datetime64[ns](1), float64(8), int64(1), object(1)
# memory usage: 2.6+ MB

# %%
df[df["Hora"] == "0"]
# Out:
# Empty DataFrame
# Columns: [Estacao, Data, Hora, Precipitacao, TempMaxima, TempMinima, Insolacao, Evaporacao Piche, Temp Comp Media, Umidade Relativa Media, Velocidade do Vento Media]
# Index: []

# %%
df2 = df.loc[df['Hora'] == 0]

# %%
df2.head()
# Out:
#    Estacao       Data Hora  Precipitacao  TempMaxima  TempMinima  Insolacao  \
# 0    83743 1961-01-01    0           NaN        32.4         NaN        1.4
# 2    83743 1961-01-02    0           NaN        30.9         NaN        0.1
# 4    83743 1961-01-03    0           NaN        28.5         NaN        4.2
# 6    83743 1961-01-04    0           NaN        28.0         NaN        6.0
# 8    83743 1961-01-05    0           NaN        28.0         NaN        2.5
#
#    Evaporacao Piche  Temp Comp Media  Umidade Relativa Media  \
# 0               2.1            27.54                   77.75
# 2               2.9            26.86                   81.75
# 4               3.3            25.98                   82.75
# 6               2.8            25.74                   81.25
# 8               2.9            25.48                   83.75
#
#    Velocidade do Vento Media
# 0                   0.000000
# 2                   0.000000
# 4                   1.000000
# ...

# %%
df3 = df2.drop(["Precipitacao", "TempMinima", "Velocidade do Vento Media"], axis=1)

# %%
df3.isna()
# Out:
#        Estacao   Data   Hora  TempMaxima  Insolacao  Evaporacao Piche  \
# 0        False  False  False       False      False             False
# 2        False  False  False       False      False             False
# 4        False  False  False       False      False             False
# 6        False  False  False       False      False             False
# 8        False  False  False       False      False             False
# 10       False  False  False       False      False             False
# 12       False  False  False       False      False             False
# 14       False  False  False       False      False             False
# 16       False  False  False       False      False             False
# 18       False  False  False       False      False             False
# 20       False  False  False       False      False             False
# 22       False  False  False       False      False             False
# ...

# %%
sns.heatmap(df3.isnull(), yticklabels=False, cbar=False, cmap="viridis")

# %%
df3.head()
# Out:
#    Estacao       Data Hora  TempMaxima  Insolacao  Evaporacao Piche  \
# 0    83743 1961-01-01    0        32.4        1.4               2.1
# 2    83743 1961-01-02    0        30.9        0.1               2.9
# 4    83743 1961-01-03    0        28.5        4.2               3.3
# 6    83743 1961-01-04    0        28.0        6.0               2.8
# 8    83743 1961-01-05    0        28.0        2.5               2.9
#
#    Temp Comp Media  Umidade Relativa Media
# 0            27.54                   77.75
# 2            26.86                   81.75
# 4            25.98                   82.75
# 6            25.74                   81.25
# 8            25.48                   83.75

# %%
df4 = df3[["Data", "TempMaxima"]]

# %%
df4
# Out:
#             Data  TempMaxima
# 0     1961-01-01        32.4
# 2     1961-01-02        30.9
# 4     1961-01-03        28.5
# 6     1961-01-04        28.0
# 8     1961-01-05        28.0
# 10    1961-01-06        31.2
# 12    1961-01-07        30.6
# 14    1961-01-08        28.3
# 16    1961-01-09        28.6
# 18    1961-01-10        28.9
# 20    1961-01-11        29.4
# 22    1961-01-12        29.4
# 24    1961-01-13        31.6
# 26    1961-01-14        31.7
# 28    1961-01-15        34.0
# 30    1961-01-16        34.7
# 32    1961-01-17        35.4
# 34    1961-01-18        36.7
# 36    1961-01-19        30.0
# 38    1961-01-20        30.4
# 40    1961-01-21        33.4
# 42    1961-01-22        34.3
# 44    1961-01-23        28.6
# 46    1961-01-24        28.3
# 48    1961-01-25        29.2
# 50    1961-01-26        25.3
# 52    1961-01-27        24.8
# 54    1961-01-28        25.6
# 56    1961-01-29        27.1
# 58    1961-01-30        27.6
# ...          ...         ...
# ...

# %%
df5 = df4.dropna()

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15840 entries, 0 to 31198
# Data columns (total 2 columns):
# Data          15840 non-null datetime64[ns]
# TempMaxima    15840 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 371.2 KB

# %%
plt.figure(figsize=(15, 7))
sns.lineplot(x="Data", y="TempMaxima", data=df5)

# %%
df5.to_csv("Rio1.csv")

# %%
df6 = df5.loc[df['Data'] > "01-01-1995"]

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5378 entries, 20356 to 31198
# Data columns (total 2 columns):
# Data          5378 non-null datetime64[ns]
# TempMaxima    5378 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 126.0 KB

# %%
plt.figure(figsize=(15, 7))
sns.lineplot(x="Data", y="TempMaxima", data=df6)

# %%
df6.describe()
# Out:
#         TempMaxima
# count  5378.000000
# mean     30.202194
# std       4.229116
# min      17.200000
# 25%      27.200000
# 50%      30.200000
# 75%      33.200000
# max      42.000000

# %%
df7 = df6 = df5.loc[df['Data'] < "01-01-1995"]

# %%
sns.distplot(df7["TempMaxima"], hist=False)
sns.distplot(df6["TempMaxima"],  hist=False)
# Out:
# C:\Users\henri\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df7.describe()
# Out:
#          TempMaxima
# count  10462.000000
# mean      27.255314
# std        3.535304
# min       16.500000
# 25%       24.700000
# 50%       27.000000
# 75%       29.500000
# max       39.000000
