# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole

# %%
m = Chem.MolFromMolFile("NiL22.mol")
print(m)
m
# Out:
# <rdkit.Chem.rdchem.Mol object at 0x7f7e344b04e0>

# %%
sm = Chem.MolToSmiles(m)

# %%
sm
# Out:
# 'Nc1c(C(=O)[O-]->[Ni+2](<-O)(<-O)(<-O)(<-O)<-[O-]C(=O)c2cnn(-c3nc4ccccc4s3)c2N)cnn1-c1nc2ccccc2s1'

# %%
p = Chem.MolFromSmiles('C1=CC=CC=N1->[Fe]')

# %%
p

# %%
m2 = Chem.MolFromSmiles(sm)

# %%
m2

# %%
m = Chem.MolFromMolFile("Est.mol")
m

# %%
sm = Chem.MolToSmiles(m)

# %% [markdown]
# sm

# %%
sm
# Out:
# 'CC1=N2->[Co+2]345(<-N6=CC=CC=C16)<-N1=CC=CC=C1C(C)=N->3O[B-](c1ccccc1)(O2)ON->4=C(C)C1=CC=CC=N->51'

# %%
m2 = Chem.MolFromSmiles(sm)

# %%
m2
