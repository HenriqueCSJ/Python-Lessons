# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole

# %%
m = Chem.MolFromMolFile("Est.mol")
m

# %%
sm = Chem.MolToSmiles(m)

# %%
sm
# Out:
# 'CC1=N2->[Co+2]345(<-N(=C(C)c6ccccn->36)O[B-](c3ccccc3)(O2)ON->4=C(C)c2ccccn->52)<-n2ccccc21'

# %%
p = Chem.MolFromSmiles('C1=CC=CC=N1->[Fe]')

# %%
p

# %%
m2 = Chem.MolFromSmiles(sm)

# %%
m2

# %%
m = Chem.MolFromMol2File("CAWCUB3.mol2")
m

# %%
sm = Chem.MolToSmiles(m)
